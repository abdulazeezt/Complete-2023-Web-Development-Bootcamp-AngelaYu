# %% [markdown]
# # CSS Specificity

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Combining CSS selectors

# %% [markdown]
# ### Grouping CSS selectors

# %%
selector, selector{}
    can be provided 2 or three whatever rules provided will be applied to the selector mentioned.
    h1, h2{}

# %% [markdown]
# ### Child ( Direct descendant)

# %% [markdown]
# selector > selector {}
# .box > p{}
#
# <div class "box">
#     <p class "done"> Do these things total </p>
# </p>

# %% [markdown]
# ### Descendent ( Should not be direct)

# %%
selector selector{}

# %% [markdown]
# ### Chaining ( Apply where all selectors are true)

# %% [markdown]
#     selectorselector{}
#     note : Should not start with a class neme.

# %% [markdown]
# ### Combining Combiners
